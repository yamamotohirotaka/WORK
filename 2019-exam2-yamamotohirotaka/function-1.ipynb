# %% [markdown]
# 以下のように2つ整数を引数にとる、add_2paramsがあります。2つの整数の和を求める関数を完成してください。

# %%
def add_2params(a, b):
    """二つの入力 a, b の和を求める"""
    return a+b  # □の中を埋める

# %% [markdown]
# add_2paramsに、2と3を引数として与えて結果を表示して下さい。

# %%
c = add_2params(2, 3)
print(c)
assert c == 5
# Out:
# 5
